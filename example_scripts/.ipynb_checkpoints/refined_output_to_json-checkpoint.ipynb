# %%
import pandas as pd
import numpy as np
from json import loads, dumps

# %%
table = pd.read_csv("/Users/farhadghassemi/Library/CloudStorage/OneDrive-Personal/Courses/Stanford/Conversational Virtual Assistant with Deep Learning/Project/Results/result_wikipedia_model_wikidata_compmix_dev_set_gpt_domain_not_passed_generic_examples_from_WWQ_compmix_max_entities_4_extended_prompt.csv")
table.sort_values(by=['question_id'], inplace=True)
table = table.reset_index()

# %%
table.head()
# Out:
#    index  question_id domain  \
# 0   1510         4966  books
# 1   1509         4966  books
# 2   1508         4966  books
# 3   2309         4967  books
# 4   2308         4967  books
#
#                                             question gold_entity_id  \
# 0  Which is the first book of the book series Div...      Q16514101
# 1  Which is the first book of the book series Div...            NaN
# 2  Which is the first book of the book series Div...            NaN
# 3   Who is the author of the book Divergent (novel)?            NaN
# 4   Who is the author of the book Divergent (novel)?        Q627192
#
#    gold_entity_label predicted_entity_id predicted_entity_label  \
# 0          Divergent                 NaN                    NaN
# 1                NaN             Q627192      Divergent (novel)
# 2                NaN             Q328212          Veronica Roth
# 3                NaN             Q328212          Veronica Roth
# 4  Divergent (novel)             Q627192      Divergent (novel)
#
#    predicted_entity_score
# 0                     NaN
# 1                  0.4737
# 2                  0.9756
# 3                  0.9756
# 4                  0.4737

# %%
table['predicted_entities'] = [{key: val} for key, val in zip(table.Stage_Name, table.Metrics)]

table['predicted_entities'] = table[['predicted_entity_id', 'predicted_entity_label']].to_dict()
table['gold_entities'] = table[['gold_entity_id', 'gold_entity_label']].values.tolist()
table.drop(['gold_entity_id', 'gold_entity_label', 'predicted_entity_id', 'predicted_entity_label', 'predicted_entity_score'], axis=1, inplace=True)

# %%
table.head()
# Out:
#    question_id    domain                                           question  \
# 0         6470     books          What was Johann Morgenstern's profession?
# 1         5136  tvseries  Who was the voice actor for Meg Griffin in Fam...
# 2         5136  tvseries  Who was the voice actor for Meg Griffin in Fam...
# 3         5136  tvseries  Who was the voice actor for Meg Griffin in Fam...
# 4         5835    soccer      What is the complete name of the player Bebé?
#
#   predicted_entities                            gold_entities
# 0                NaN  [Q67149, Johann Karl Simon Morgenstern]
# 1                NaN                   [Q908772, Meg Griffin]
# 2                NaN                      [Q5930, Family Guy]
# 3                NaN                               [nan, nan]
# 4                NaN                          [Q299450, Bebé]

# %%
table2 = table.groupby("question_id").agg({'domain': 'first', 'question': 'first', 'predicted_entities': lambda x: list(x), 'gold_entities': lambda x: list(x)})
table2['gold_entities'] = table2['gold_entities'].apply(lambda x: [xi for xi in x if not pd.isna(xi[0])])
table2['predicted_entities'] = table2['predicted_entities'].apply(lambda x: [xi for xi in x if not pd.isna(xi[0])])

# %%
table2.head()
# Out:
#             domain                                           question  \
# question_id
# 4966         books  Which is the first book of the book series Div...
# 4967         books   Who is the author of the book Divergent (novel)?
# 4968         books  What is the date of birth of the Divergent's a...
# 4969         books  Which is the second book of the series Divergent?
# 4970         books  What is the publication date of the Insurgent ...
#
#                                             predicted_entities  \
# question_id
# 4966         [[Q328212, Veronica Roth], [Q627192, Divergent...
# 4967         [[Q627192, Divergent (novel)], [Q328212, Veron...
# 4968                                [[Q328212, Veronica Roth]]
# 4969                                                        []
# 4970                           [[Q5918512, Insurgent (novel)]]
#
#                                                 gold_entities
# question_id
# 4966                                 [[Q16514101, Divergent]]
# 4967                           [[Q627192, Divergent (novel)]]
# 4968         [[Q328212, Veronica Roth], [Q627192, Divergent]]
# 4969                                 [[Q16514101, Divergent]]
# 4970                          [[Q5918512, Insurgent (novel)]]

# %%
result = table2.to_json("/Users/farhadghassemi/Library/CloudStorage/OneDrive-Personal/Courses/Stanford/Conversational Virtual Assistant with Deep Learning/Project/Results/result_wikipedia_model_wikidata_compmix_dev_set_gpt_domain_not_passed_generic_examples_from_WWQ_compmix_max_entities_4_extended_prompt.json", orient="records", indent=3)
